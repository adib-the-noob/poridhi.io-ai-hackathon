# %%
# !pip install sentence-transformers datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 34.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 7.2 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# Load the WDC Products 2017 dataset
dataset = load_dataset("wdc/products-2017", split='train')
print(dataset[0])  # View the first example
from datasets import load_dataset

# Load the WDC Products 2017 dataset
dataset = load_dataset("wdc/products-2017", split='train')

product_list = []
for row in dataset:
    product_list.append({
        "id": row["id_left"],
        "title": row["title_left"],
        "description": row["description_left"]
    })
    product_list.append({
        "id": row["id_right"],
        "title": row["title_right"],
        "description": row["description_right"]
    })
print(product_list[:10])
# Out:
# {'pair_id': '14219585#11723285', 'label': 0, 'id_left': 14219585, 'category_left': 'Computers_and_Accessories', 'cluster_id_left': 521249, 'brand_left': None, 'title_left': ' "Apple - Mac Pro Desktop Computer 6-Core Intel® Xeon® Processor 16GB Memory 256GB Flash Storage Black"@en-US', 'description_left': '"Apple Mac Pro MD878LL/A Desktop: Designed for professional movie editing, graphics work and multiple Ultra HD 4K displays, this impressive computer provides top-tier power and connectivity. The eye-catching body provides efficient, quiet cooling and fits easily on a desk."@en-US ', 'price_left': None, 'specTableContent_left': None, 'id_right': 11723285, 'category_right': 'Computers_and_Accessories', 'cluster_id_right': 9835048, 'brand_right': '"HP Enterprise"', 'title_right': ' "COMPAQ PL ML530R G3 Xeon 3.0GHz 1GB", "Null" Price 271246-001" 1GB Wholesale COMPAQ', 'description_right': '"Description:\n271246-001  Proliant Xeon 3.0GHz ML530 G2 Rack 1GB\nPart# 271246-001\n\n\n" ', 'pri
# ...
